# %% [markdown]
# # **Reporte del Modelo Baseline**
# ---

# %%
# Librerias
# !pip install optuna
import os
import requests
import logging
import optuna
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.8-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 6.4 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 8.8 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.8-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 8.1 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.8 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
# Funcion para crear el objeto de creación de logs
def create_logger():
  logging.basicConfig(level = logging.INFO, format = '%(asctime)s - %(levenname)s - %(message)s')
  logger = logging.getLogger('Logger')
  logger.info('Logger creado')
  return logger

# %%
# Función de consumo a la base de datos de Firebase para cargar el DataSet
def download_firebase(url, logger):
  logger.info("Extrayendo el archivo desde Firebase")
  df = None
  try:
    df = pd.read_csv(url)
    logger.info("Archivo cargado")
  except requests.exceptions.RequestException as e:
    logger.info(f"Error al descargar el archivo CSV: {e}")
  except pd.errors.EmptyDataError:
    logger.info("El archivo CSV está vacío.")
  except Exception as e:
    logger.info(f"Ocurrió un error inesperado: {e}")
  return df

# %%
# Cargar DataSet
url = 'https://firebasestorage.googleapis.com/v0/b/personalwp-8822c.appspot.com/o/diabetes_prediction_dataset.csv?alt=media&token=4d70d154-c3d0-4fa0-a3aa-9b9972dd3b95'
logger = create_logger()
df = download_firebase(url, logger)

# %%
# Eliminación de valores atípicos y duplicados
seventy_fifth = df['bmi'].quantile(0.75)
twenty_fifth = df['bmi'].quantile(0.25)
iqr = seventy_fifth - twenty_fifth
upper = seventy_fifth + (10 * iqr)
outliers_bmi_upper = df[(df['bmi'] > upper)]
df = pd.merge(df, outliers_bmi_upper, indicator = True, how = 'outer').query('_merge == "left_only"').drop('_merge', axis = 1)
df = df.drop_duplicates(keep = "first")

# %%
# Variables Categóricas a Numéricas
df['gender'] = pd.factorize(df['gender'])[0]
df['smoking_history'] = pd.factorize(df['smoking_history'])[0]

# %% [markdown]
# ## **Implementación del Modelo**

# %% [markdown]
# ### **Partición de Datos**

# %%
# Separación de la 'Data' (Características)
X = df.drop(columns = 'diabetes')
X.shape
# Out:
# (96143, 8)

# %%
# Separación del 'Target' (Variable objetivo)
y = df['diabetes']
y.shape
# Out:
# (96143,)

# %%
# Partición de los datos: 70% para entrenamiento, 30% para prueba y estratificación en las etiquetas (y)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)

# %%
# Validación de la partición de los datos
print(f'Número de muestras en entrenamiento: {X_train.shape[0]}')
print(f'Número de muestras en prueba: {X_test.shape[0]}')
print(f'Número de características: {X_train.shape[1]}')
# Out:
# Número de muestras en entrenamiento: 67300
# Número de muestras en prueba: 28843
# Número de características: 8

# %%
# Distribución de la variable objetivo en los conjuntos de entrenamiento y prueba
print(f'Distribución de clases en entrenamiento: {np.bincount(y_train)}')
print(f'Distribución de clases en prueba: {np.bincount(y_test)}')
# Out:
# Distribución de clases en entrenamiento: [61363  5937]
# Distribución de clases en prueba: [26298  2545]

# %% [markdown]
# ### **Entrenamiento del Modelo**

# %%
# Función para la definición y entrenamiento de hiperparámetros a explorar
def objective(trial):
  max_depth = trial.suggest_int("max_depth", 1, 100)
  model = DecisionTreeClassifier(max_depth = max_depth)
  model.fit(X_train, y_train)
  y_pred = model.predict(X_test)
  score = accuracy_score(y_test, y_pred)
  return score

# %%
# Exploración de hiperparámetros
study = optuna.create_study(direction = "maximize", storage = "sqlite:///hp.db", study_name = "DecisionTreeClassifier")
study.optimize(func = objective, n_trials = 100, n_jobs = -1)
# Out:
# [I 2024-12-11 08:53:33,844] A new study created in RDB with name: KNeighborsClassifier
# [I 2024-12-11 08:53:34,290] Trial 0 finished with value: 0.9709114863225046 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:34,430] Trial 1 finished with value: 0.9516693825191554 and parameters: {'max_depth': 95}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:34,857] Trial 3 finished with value: 0.9709114863225046 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:34,968] Trial 2 finished with value: 0.9516000416045488 and parameters: {'max_depth': 36}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:35,421] Trial 4 finished with value: 0.9517387234337621 and parameters: {'max_depth': 97}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:35,551] Trial 5 finished with value: 0.9514266893180321 and parameters: {'max_depth': 96}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:36,000] Trial 6 finished with value: 0.9513920188607288 and parameters: {'max_depth': 80}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:36,110] Trial 7 finished with value: 0.9513573484034255 and parameters: {'max_depth': 35}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:36,640] Trial 8 finished with value: 0.9514266893180321 and parameters: {'max_depth': 40}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:36,686] Trial 9 finished with value: 0.9526748257809521 and parameters: {'max_depth': 54}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:36,944] Trial 10 finished with value: 0.9709114863225046 and parameters: {'max_depth': 3}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:36,954] Trial 11 finished with value: 0.951842734805672 and parameters: {'max_depth': 1}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:37,421] Trial 13 finished with value: 0.9626252470270082 and parameters: {'max_depth': 17}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:37,431] Trial 12 finished with value: 0.9615851333079083 and parameters: {'max_depth': 18}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:37,789] Trial 14 finished with value: 0.9605450195888083 and parameters: {'max_depth': 19}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:37,874] Trial 15 finished with value: 0.9621398606247616 and parameters: {'max_depth': 18}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:38,170] Trial 16 finished with value: 0.952154768921402 and parameters: {'max_depth': 66}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:38,251] Trial 17 finished with value: 0.9517040529764588 and parameters: {'max_depth': 51}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:38,455] Trial 18 finished with value: 0.9708074749505946 and parameters: {'max_depth': 10}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:38,544] Trial 19 finished with value: 0.9708074749505946 and parameters: {'max_depth': 10}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:38,828] Trial 20 finished with value: 0.9534722462989287 and parameters: {'max_depth': 26}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:38,920] Trial 21 finished with value: 0.9521200984640987 and parameters: {'max_depth': 29}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:39,001] Trial 22 finished with value: 0.951842734805672 and parameters: {'max_depth': 1}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:39,163] Trial 23 finished with value: 0.9709114863225046 and parameters: {'max_depth': 5}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:39,281] Trial 24 finished with value: 0.9707034635786846 and parameters: {'max_depth': 9}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:39,452] Trial 25 finished with value: 0.9704607703775613 and parameters: {'max_depth': 11}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:39,647] Trial 26 finished with value: 0.953610928128142 and parameters: {'max_depth': 26}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:39,821] Trial 27 finished with value: 0.9533335644697154 and parameters: {'max_depth': 26}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:39,993] Trial 28 finished with value: 0.9519814166348854 and parameters: {'max_depth': 43}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:40,170] Trial 29 finished with value: 0.9520854280067954 and parameters: {'max_depth': 44}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:40,350] Trial 30 finished with value: 0.9513920188607288 and parameters: {'max_depth': 81}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:40,517] Trial 31 finished with value: 0.9514960302326387 and parameters: {'max_depth': 81}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:40,590] Trial 32 finished with value: 0.9709114863225046 and parameters: {'max_depth': 4}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:40,732] Trial 33 finished with value: 0.9709114863225046 and parameters: {'max_depth': 3}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:40,833] Trial 34 finished with value: 0.9709114863225046 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:41,056] Trial 35 finished with value: 0.9690392816281247 and parameters: {'max_depth': 13}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:41,164] Trial 36 finished with value: 0.9670630655618347 and parameters: {'max_depth': 14}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:41,400] Trial 37 finished with value: 0.9670630655618347 and parameters: {'max_depth': 14}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:41,510] Trial 38 finished with value: 0.9557604964809486 and parameters: {'max_depth': 22}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:41,751] Trial 39 finished with value: 0.9512533370315155 and parameters: {'max_depth': 31}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:41,885] Trial 40 finished with value: 0.9512186665742122 and parameters: {'max_depth': 34}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:41,985] Trial 41 finished with value: 0.9709114863225046 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:42,116] Trial 42 finished with value: 0.9709114863225046 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:42,207] Trial 43 finished with value: 0.9709114863225046 and parameters: {'max_depth': 5}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:42,281] Trial 44 finished with value: 0.951842734805672 and parameters: {'max_depth': 1}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:42,368] Trial 45 finished with value: 0.951842734805672 and parameters: {'max_depth': 1}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:42,624] Trial 46 finished with value: 0.9584994626079117 and parameters: {'max_depth': 20}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:42,729] Trial 47 finished with value: 0.954755053219152 and parameters: {'max_depth': 23}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:42,993] Trial 48 finished with value: 0.9517387234337621 and parameters: {'max_depth': 62}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:43,103] Trial 49 finished with value: 0.9519814166348854 and parameters: {'max_depth': 64}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:43,348] Trial 50 finished with value: 0.951530700689942 and parameters: {'max_depth': 91}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:43,438] Trial 51 finished with value: 0.9644281108067816 and parameters: {'max_depth': 16}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:43,604] Trial 52 finished with value: 0.9707728044932913 and parameters: {'max_depth': 7}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:43,694] Trial 53 finished with value: 0.9709114863225046 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:43,808] Trial 54 finished with value: 0.9709114863225046 and parameters: {'max_depth': 4}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:43,906] Trial 55 finished with value: 0.9709114863225046 and parameters: {'max_depth': 3}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:44,116] Trial 56 finished with value: 0.970426099920258 and parameters: {'max_depth': 11}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:44,201] Trial 57 finished with value: 0.9707034635786846 and parameters: {'max_depth': 9}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:44,397] Trial 58 finished with value: 0.9708074749505946 and parameters: {'max_depth': 10}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:44,538] Trial 59 finished with value: 0.9646014630932982 and parameters: {'max_depth': 16}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:44,723] Trial 60 finished with value: 0.9629372811427382 and parameters: {'max_depth': 17}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:44,866] Trial 62 finished with value: 0.951842734805672 and parameters: {'max_depth': 1}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:44,916] Trial 61 finished with value: 0.9690046111708214 and parameters: {'max_depth': 13}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:45,139] Trial 63 finished with value: 0.9708768158652012 and parameters: {'max_depth': 8}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:45,213] Trial 64 finished with value: 0.9707728044932913 and parameters: {'max_depth': 7}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:45,367] Trial 65 finished with value: 0.9709114863225046 and parameters: {'max_depth': 4}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:45,428] Trial 66 finished with value: 0.9709114863225046 and parameters: {'max_depth': 3}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:45,692] Trial 67 finished with value: 0.9698713726034046 and parameters: {'max_depth': 12}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:45,772] Trial 68 finished with value: 0.9699407135180113 and parameters: {'max_depth': 12}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:46,085] Trial 69 finished with value: 0.9514266893180321 and parameters: {'max_depth': 100}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:46,173] Trial 70 finished with value: 0.9587768262663384 and parameters: {'max_depth': 20}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:46,445] Trial 71 finished with value: 0.9579794057483618 and parameters: {'max_depth': 20}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:46,453] Trial 72 finished with value: 0.9708768158652012 and parameters: {'max_depth': 8}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:46,693] Trial 74 finished with value: 0.9709114863225046 and parameters: {'max_depth': 5}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:46,742] Trial 73 finished with value: 0.9709114863225046 and parameters: {'max_depth': 5}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:46,921] Trial 75 finished with value: 0.9709114863225046 and parameters: {'max_depth': 3}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:47,130] Trial 76 finished with value: 0.9511493256596054 and parameters: {'max_depth': 57}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:47,240] Trial 77 finished with value: 0.9661269632146448 and parameters: {'max_depth': 15}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:47,538] Trial 78 finished with value: 0.9662656450438581 and parameters: {'max_depth': 15}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:47,734] Trial 79 finished with value: 0.9707034635786846 and parameters: {'max_depth': 9}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:48,011] Trial 80 finished with value: 0.9707034635786846 and parameters: {'max_depth': 9}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:48,034] Trial 81 finished with value: 0.9709114863225046 and parameters: {'max_depth': 2}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:48,461] Trial 83 finished with value: 0.9709114863225046 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:48,463] Trial 82 finished with value: 0.9709114863225046 and parameters: {'max_depth': 6}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:48,697] Trial 84 finished with value: 0.951842734805672 and parameters: {'max_depth': 1}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:48,713] Trial 85 finished with value: 0.951842734805672 and parameters: {'max_depth': 1}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:49,245] Trial 86 finished with value: 0.9703914294629546 and parameters: {'max_depth': 11}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:49,324] Trial 87 finished with value: 0.9514266893180321 and parameters: {'max_depth': 73}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:49,754] Trial 88 finished with value: 0.9542696668169053 and parameters: {'max_depth': 23}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:49,806] Trial 89 finished with value: 0.9707728044932913 and parameters: {'max_depth': 7}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:50,199] Trial 91 finished with value: 0.9709114863225046 and parameters: {'max_depth': 4}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:50,431] Trial 90 finished with value: 0.9521200984640987 and parameters: {'max_depth': 47}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:50,613] Trial 92 finished with value: 0.9709114863225046 and parameters: {'max_depth': 5}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:50,991] Trial 93 finished with value: 0.9523974621225254 and parameters: {'max_depth': 38}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:51,073] Trial 94 finished with value: 0.9689005997989113 and parameters: {'max_depth': 13}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:51,301] Trial 95 finished with value: 0.9704954408348646 and parameters: {'max_depth': 11}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:51,390] Trial 96 finished with value: 0.9708074749505946 and parameters: {'max_depth': 10}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:51,557] Trial 97 finished with value: 0.9707728044932913 and parameters: {'max_depth': 7}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:51,651] Trial 98 finished with value: 0.9707728044932913 and parameters: {'max_depth': 7}. Best is trial 0 with value: 0.9709114863225046.
# [I 2024-12-11 08:53:51,714] Trial 99 finished with value: 0.9709114863225046 and parameters: {'max_depth': 3}. Best is trial 0 with value: 0.9709114863225046.

# %%
# Mejor hiperparámetro
params = study.best_params
print(params)
# Out:
# {'max_depth': 6}

# %%
# Mejor metrica
score = study.best_value
print(score)
# Out:
# 0.9709114863225046

# %% [markdown]
# **Universidad Nacional de Colombia** - *Facultad de Ingeniería*
